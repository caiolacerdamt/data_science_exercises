# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report

# %%
df = pd.read_csv("../datasets/WA_Fn-UseC_-Telco-Customer-Churn.csv")

df.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95       1889.5     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
df.drop(["customerID"], axis=1, inplace=True)

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.head()
# Out:
#    SeniorCitizen  tenure  ...  TotalCharges_999.9  Churn_Yes
# 0              0       1  ...               False      False
# 1              0      34  ...               False      False
# 2              0       2  ...               False       True
# 3              0      45  ...               False      False
# 4              0       2  ...               False       True
#
# [5 rows x 6560 columns]

# %%
X = df.drop("Churn_Yes", axis=1)
y = df["Churn_Yes"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train) # X_train recebe o fit_transform()
X_test = scaler.transform(X_test) # X_test recebe apenas o transform()

# %%
model = LogisticRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))

# -------------
# TP   |   FN
# FP   |   TN
# -------------
# TP (True Positive) -> Modelo Previu que era 1, e era 1.
# TN (True Negative) -> Modelo Previu que era 0, e era 0.
# FP (False Positive) -> Modelo Previu que era 1, e era 0.
# FN (False Negative) -> Modelo Previu que era 0, e era 1.
# Out:
# [[3879  243]
#  [ 998  515]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.80      0.94      0.86      4122
#         True       0.68      0.34      0.45      1513
#
#     accuracy                           0.78      5635
#    macro avg       0.74      0.64      0.66      5635
# weighted avg       0.76      0.78      0.75      5635
